# %% [markdown]
# ## The dataset consisting of 70 rows & 3 columns scraped from
# ## https://www.indianmirror.com/india-post/indianpincode.html using requests & BeautifulSoup libraries. The columns consists of Name of cities in UttarPradesh, their Latitude & Longitude.

# %% [markdown]
# ## Dataset

# %%
from IPython.display import Image
Image("DataFrame.jpg")
